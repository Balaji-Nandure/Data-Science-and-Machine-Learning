# %%
# for loop
for i in range(5):
    print(i)

range(2, 5)  # 2,3,4

# start, end, step
range(2, 10, 2)  # 2, 4, 6, 8
# Out:
# 0
# 1
# 2
# 3
# 4
# range(2, 5)

# %%
name = "Balaji Nandure"
for i in name:
    print(i) # B, a, l, a, j, i,  , N, a, n, d, u, r, e
# Out:
# B
# a
# l
# a
# j
# i
#
# N
# a
# n
# d
# u
# r
# e
