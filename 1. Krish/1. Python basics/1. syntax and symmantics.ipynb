# %%
# single line comment

'''
    Multi line comment
''' 

# python is case sensitive -> balaji and Balaji both are different variables

# %%
# python uses indentation to define the scope of the block of code

# %%
# Line continuation is done using backslash (\)
total = 100 + \
    50 + \
    25
print(total)
# Out:
# 175

# %%
# multiple statements in a single line
a = 1; b = 2; c = 3

# %%
# Variable assignment
name = "Balaji"
type(name)
# Out:
# str

# %%
# typecasting is allowed
score = 100
print(type(score))
score = "Anuj"
print(type(score))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## Code examples of indentation
if True:
    print("Correct Indentation")
    if False:
        print("This wont print")
    print("This will print")
print("Outide the if block")
# Out:
# Correct Indentation
# This will print
# Outide the if block
